# %% [markdown]
# Imports

# %%
import scrapy

from pysft.core.TASE_Scraper.TASE_Scraper.spiders.s_themarker import TheMarkerSpider

# %% [markdown]
# TASE Indicators

# %%
indicators = ["5138094", "1104249", "1144633", "1183441", "5111422", "5117379", "1159094", "1159169", "1186063"]

mtf = "5138094"
etf = "1144633"
stock = "1104249"

# %% [markdown]
# Crawl for mtf

# %%
spider = TheMarkerSpider(mtf)
